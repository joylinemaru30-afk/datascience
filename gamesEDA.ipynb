# %%
import pandas
data=pandas.read_csv("datasets/lists.csv")
data
# Out:
#                                          Game   Copies sold  \
# 0                         Marvel's Spider-Man    20 million
# 1                                  God of War  19.5 million
# 2                  Uncharted 4: A Thief's End    16 million
# 3                    The Witcher 3: Wild Hunt  10.8 million
# 4                      The Last of Us Part II    10 million
# 5                           Horizon Zero Dawn    10 million
# 6                   The Last of Us Remastered    10 million
# 7                           Ghost of Tsushima  9.73 million
# 8                       Star Wars Battlefront  8.42 million
# 9                          Gran Turismo Sport     8 million
# 10                        Infamous Second Son     6 million
# 11                      Detroit: Become Human   5.5 million
# 12                   Final Fantasy VII Remake     5 million
# 13                      Monster Hunter: World  4.67 million
# 14                             Cyberpunk 2077  3.83 million
# ...

# %%
data.describe()
# Out:
#                        Game Copies sold    Release date[a]  \
# count                    33          33                 33
# unique                   33          24                 32
# top     Marvel's Spider-Man   2 million  November 15, 2013
# freq                      1           4                  2
#
#                    Genre(s) Developer(s)                    Publisher(s)
# count                    33           33                              33
# unique                   15           23                              12
# top     Action role-playing  Square Enix  Sony Interactive Entertainment
# freq                     11            4                               8

# %%
data.groupby(["Game","Release date[a]"]).size()
# Out:
# Game                                       Release date[a]
# Battlefield 1                              October 21, 2016      1
# Bloodborne                                 March 24, 2015        1
# Crash Bandicoot N. Sane Trilogy            June 30, 2017         1
# Cyberpunk 2077                             December 10, 2020     1
# Detroit: Become Human                      May 25, 2018          1
# Dragon Quest XI: Echoes of an Elusive Age  July 29, 2017         1
# Driveclub                                  October 7, 2014       1
# FIFA 17                                    September 27, 2016    1
# Final Fantasy VII Remake                   April 10, 2020        1
# Final Fantasy XII: The Zodiac Age          July 11, 2017         1
# Final Fantasy XV                           November 29, 2016     1
# Ghost of Tsushima                          July 17, 2020         1
# God of War                                 April 20, 2018        1
# ...

# %%
data.groupby(["Genre(s)","Publisher(s)"]).size()
# Out:
# Genre(s)                                   Publisher(s)
# Action role-playing                        CD Projekt                                           2
#                                            Capcom                                               1
#                                            Sony Computer Entertainment                          1
#                                            Sony Interactive Entertainment                       1
#                                            Square Enix                                          4
#                                            WW: Sony Interactive Entertainment JP: Koei Tecmo    2
# Action-adventure                           Rockstar Games                                       1
#                                            Sony Computer Entertainment                          1
#                                            Sony Interactive Entertainment                       2
# ...

# %%
data["Publisher(s)"].value_counts().plot.pie(autopct="%1f%%")
# Out:
# <AxesSubplot: ylabel='count'>

# %%
data.groupby(["Release date[a]","Publisher(s)"]).size()
# Out:
# Release date[a]     Publisher(s)
# April 10, 2020      Square Enix                                          1
# April 20, 2018      Sony Interactive Entertainment                       1
# December 10, 2020   CD Projekt                                           1
# February 23, 2017   Square Enix                                          1
# February 28, 2017   Sony Interactive Entertainment                       1
# February 7, 2017    WW: Sony Interactive Entertainment JP: Koei Tecmo    1
# January 25, 2019    Square Enix                                          1
# January 26, 2018    Capcom                                               1
# July 11, 2017       Square Enix                                          1
# July 17, 2020       Sony Interactive Entertainment                       1
# July 29, 2014       Sony Computer Entertainment                          1
# July 29, 2017       Square Enix                                          1
# ...

# %%
data.groupby(["Genre(s)","Publisher(s)"]).size()
# Out:
# Genre(s)                                   Publisher(s)
# Action role-playing                        CD Projekt                                           2
#                                            Capcom                                               1
#                                            Sony Computer Entertainment                          1
#                                            Sony Interactive Entertainment                       1
#                                            Square Enix                                          4
#                                            WW: Sony Interactive Entertainment JP: Koei Tecmo    2
# Action-adventure                           Rockstar Games                                       1
#                                            Sony Computer Entertainment                          1
#                                            Sony Interactive Entertainment                       2
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="Publisher(s)",data=data,palette="winter")
plt.title("distribution of publisher(s)")
# Out:
# /tmp/ipykernel_9276/2967732324.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Publisher(s)",data=data,palette="winter")
# Text(0.5, 1.0, 'distribution of publisher(s)')
